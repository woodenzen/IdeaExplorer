# %%
import pandas as pd

# %%
df = pd.read_csv('data.csv')

# %%
df
# Out:
#                                                   title              uuid  \
# 0                                     A-3 sides of Risk  ['202005211026']
# 1                                       B-Owning It All  ['202101232137']
# 2                                         I'm Sorry For  ['202007311455']
# 3                       Writing For Many Readers-Selves  ['202108311609']
# 4                                         B-Fire Season  ['202005111628']
# ...                                                 ...               ...
# 3153                 Humanity's And Landscape's Divorce  ['202104190601']
# 3154  Architectures for a more flexible mnemonic medium  ['202110010816']
# 3155                                    Procrastination  ['201901021254']
# 3156                                Temporal reordering  ['201901151751']
# 3157                    Animal Mentions in Zettelkasten  ['202105260734']
#
#                                              tags  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3158 entries, 0 to 3157
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   title        3151 non-null   object
#  1   uuid         3158 non-null   object
#  2   tags         3158 non-null   object
#  3   links        3158 non-null   object
#  4   last_mod_dt  3158 non-null   object
#  5   word_count   3158 non-null   int64
# dtypes: int64(1), object(5)
# memory usage: 148.2+ KB

# %% [markdown]
# Notes.
# `df.set_index['uuid']` (optionally if needed , inplace+true)
# `df.reset_index(inplace=true)`
# Sets the uuid as the index.
# Allows `de.loc[202201121254]`
#
# Filtering
# make and assign a bolean mask to a dataframe
# `filt = (df['last'| == 'value'])`
# `df[filt]`
# `df.loc[filt, 'column']` give only the columns of the filtered rows.
#
# & = and
# | = or
# ~ = a negastion of filter
#
# `filt=df['column'].str.contains('value', na=False)` filtering the contents of each row in a column by a string
# `df.loc[filt, 'column']` give only the columns of the filtered rows.

# %%
filt = (df['links'].str.contains('202101232137'))

# %%
df.loc[filt, ['last_mod_dt', 'title']]
# Out:
#                    last_mod_dt  \
# 1     Thu Dec 08 08:04:04 2022
# 161   Wed Jul 13 08:51:03 2022
# 243   Tue Jan 17 15:55:53 2023
# 374   Sat Jan 29 08:33:35 2022
# 557   Wed Jul 13 08:51:03 2022
# 780   Mon May 24 17:34:27 2021
# 838   Sat Feb 27 05:30:16 2021
# 853   Tue Dec 20 12:04:01 2022
# 868   Wed May 18 20:22:06 2022
# 923   Wed Jul 13 08:51:03 2022
# 1126  Sun Apr 25 10:30:39 2021
# 1260  Wed Jul 13 08:51:03 2022
# 1287  Sat Feb 27 05:30:16 2021
# 1692  Thu Dec 30 20:04:40 2021
# 2443  Wed Jul 13 08:51:03 2022
# 2529  Thu Mar 04 07:14:45 2021
# 2644  Sat Feb 27 05:30:16 2021
# 2966  Sat Feb 27 05:30:16 2021
# 3084  Wed Jan 26 10:08:40 2022
# 3124  Wed Jul 13 08:51:03 2022
# 3140  Mon Sep 19 20:16:23 2022
#
#                                                 title
# 1                                     B-Owning It All
# 161                             B-Going Away to Think
# 243                            Abundance Of Essayists
# ...

# %% [markdown]
# `df.loc` then the filter and a dictionary of the wanted columns

# %%
df.rename(columns={'oldValue' : 'newValue'})
# Out:
#                                                   title              uuid  \
# 0                                     A-3 sides of Risk  ['202005211026']
# 1                                       B-Owning It All  ['202101232137']
# 2                                         I'm Sorry For  ['202007311455']
# 3                       Writing For Many Readers-Selves  ['202108311609']
# 4                                         B-Fire Season  ['202005111628']
# ...                                                 ...               ...
# 3153                 Humanity's And Landscape's Divorce  ['202104190601']
# 3154  Architectures for a more flexible mnemonic medium  ['202110010816']
# 3155                                    Procrastination  ['201901021254']
# 3156                                Temporal reordering  ['201901151751']
# 3157                    Animal Mentions in Zettelkasten  ['202105260734']
#
#                                              tags  \
# ...
